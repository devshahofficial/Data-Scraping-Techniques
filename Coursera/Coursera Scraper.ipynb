# %%
# retrieved from HTTP Toolkit

data = [
  {
    "data": {
      "ExternallyAccessibleNostosV1Resource": {
        "getAllProperties": {
          "elements": [
            {
              "id": "data-science",
              "content": {
                "skill_data": [
                  {
                    "rank": 1,
                    "listIdentifier": "python",
                    "url": "https://www.coursera.org/courses?query=python"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=sql",
                    "rank": 2,
                    "listIdentifier": "sql"
                  },
                  {
                    "rank": 3,
                    "url": "https://www.coursera.org/courses?query=microsoft%20excel",
                    "listIdentifier": "microsoft excel"
                  },
                  {
                    "listIdentifier": "excel",
                    "rank": 4,
                    "url": "https://www.coursera.org/courses?query=excel"
                  },
                  {
                    "rank": 5,
                    "listIdentifier": "machine learning",
                    "url": "https://www.coursera.org/courses?query=machine%20learning"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=data%20science",
                    "listIdentifier": "data science",
                    "rank": 6
                  },
                  {
                    "rank": 7,
                    "url": "https://www.coursera.org/courses?query=data%20analytics",
                    "listIdentifier": "data analytics"
                  },
                  {
                    "rank": 8,
                    "url": "https://www.coursera.org/courses?query=power%20bi",
                    "listIdentifier": "power bi"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=artificial%20intelligence",
                    "listIdentifier": "artificial intelligence",
                    "rank": 9
                  },
                  {
                    "listIdentifier": "statistics",
                    "url": "https://www.coursera.org/courses?query=statistics",
                    "rank": 10
                  }
                ]
              },
              "__typename": "ExternallyAccessibleNostosV1"
            },
            {
              "id": "business",
              "content": {
                "skill_data": [
                  {
                    "listIdentifier": "project management",
                    "rank": 1,
                    "url": "https://www.coursera.org/courses?query=project%20management"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=microsoft%20excel",
                    "listIdentifier": "microsoft excel",
                    "rank": 2
                  },
                  {
                    "rank": 3,
                    "listIdentifier": "excel",
                    "url": "https://www.coursera.org/courses?query=excel"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=blockchain",
                    "rank": 4,
                    "listIdentifier": "blockchain"
                  },
                  {
                    "rank": 5,
                    "url": "https://www.coursera.org/courses?query=digital%20marketing",
                    "listIdentifier": "digital marketing"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=data%20analytics",
                    "rank": 6,
                    "listIdentifier": "data analytics"
                  },
                  {
                    "rank": 7,
                    "url": "https://www.coursera.org/courses?query=power%20bi",
                    "listIdentifier": "power bi"
                  },
                  {
                    "listIdentifier": "design",
                    "rank": 8,
                    "url": "https://www.coursera.org/courses?query=design"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=communication%20skills",
                    "listIdentifier": "communication skills",
                    "rank": 9
                  },
                  {
                    "listIdentifier": "marketing",
                    "url": "https://www.coursera.org/courses?query=marketing",
                    "rank": 10
                  }
                ]
              },
              "__typename": "ExternallyAccessibleNostosV1"
            },
            {
              "id": "computer-science",
              "content": {
                "skill_data": [
                  {
                    "rank": 1,
                    "listIdentifier": "python",
                    "url": "https://www.coursera.org/courses?query=python"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=sql",
                    "rank": 2,
                    "listIdentifier": "sql"
                  },
                  {
                    "listIdentifier": "cybersecurity",
                    "rank": 3,
                    "url": "https://www.coursera.org/courses?query=cybersecurity"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=java",
                    "listIdentifier": "java",
                    "rank": 4
                  },
                  {
                    "rank": 5,
                    "url": "https://www.coursera.org/courses?query=blockchain",
                    "listIdentifier": "blockchain"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=web%20development",
                    "rank": 6,
                    "listIdentifier": "web development"
                  },
                  {
                    "rank": 7,
                    "url": "https://www.coursera.org/courses?query=c%2B%2B",
                    "listIdentifier": "c++"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=artificial%20intelligence",
                    "listIdentifier": "artificial intelligence",
                    "rank": 8
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=aws",
                    "listIdentifier": "aws",
                    "rank": 9
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=product%20management",
                    "listIdentifier": "product management",
                    "rank": 10
                  }
                ]
              },
              "__typename": "ExternallyAccessibleNostosV1"
            },
            {
              "id": "information-technology",
              "content": {
                "skill_data": [
                  {
                    "rank": 1,
                    "listIdentifier": "google",
                    "url": "https://www.coursera.org/courses?query=google"
                  },
                  {
                    "listIdentifier": "cybersecurity",
                    "url": "https://www.coursera.org/courses?query=cybersecurity",
                    "rank": 2
                  },
                  {
                    "rank": 3,
                    "url": "https://www.coursera.org/courses?query=aws",
                    "listIdentifier": "aws"
                  },
                  {
                    "listIdentifier": "linux",
                    "url": "https://www.coursera.org/courses?query=linux",
                    "rank": 4
                  },
                  {
                    "rank": 5,
                    "listIdentifier": "devops",
                    "url": "https://www.coursera.org/courses?query=devops"
                  },
                  {
                    "listIdentifier": "sap",
                    "rank": 6,
                    "url": "https://www.coursera.org/courses?query=sap"
                  },
                  {
                    "rank": 7,
                    "url": "https://www.coursera.org/courses?query=ethical%20hacking",
                    "listIdentifier": "ethical hacking"
                  },
                  {
                    "rank": 8,
                    "url": "https://www.coursera.org/courses?query=data%20engineering",
                    "listIdentifier": "data engineering"
                  },
                  {
                    "listIdentifier": "kubernetes",
                    "url": "https://www.coursera.org/courses?query=kubernetes",
                    "rank": 9
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=microsoft",
                    "listIdentifier": "microsoft",
                    "rank": 10
                  }
                ]
              },
              "__typename": "ExternallyAccessibleNostosV1"
            },
            {
              "id": "language-learning",
              "content": {
                "skill_data": [
                  {
                    "rank": 1,
                    "listIdentifier": "english speaking",
                    "url": "https://www.coursera.org/courses?query=english%20speaking"
                  },
                  {
                    "listIdentifier": "english",
                    "rank": 2,
                    "url": "https://www.coursera.org/courses?query=english"
                  },
                  {
                    "rank": 3,
                    "listIdentifier": "spanish",
                    "url": "https://www.coursera.org/courses?query=spanish"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=french%20language",
                    "listIdentifier": "french language",
                    "rank": 4
                  },
                  {
                    "rank": 5,
                    "listIdentifier": "korean",
                    "url": "https://www.coursera.org/courses?query=korean"
                  },
                  {
                    "rank": 6,
                    "url": "https://www.coursera.org/courses?query=chinese",
                    "listIdentifier": "chinese"
                  },
                  {
                    "rank": 7,
                    "url": "https://www.coursera.org/courses?query=language",
                    "listIdentifier": "language"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=english%20grammar",
                    "rank": 8,
                    "listIdentifier": "english grammar"
                  },
                  {
                    "listIdentifier": "french",
                    "url": "https://www.coursera.org/courses?query=french%20language",
                    "rank": 9
                  },
                  {
                    "url": "https://www.coursera.org/search?query=japanese",
                    "listIdentifier": "japanese",
                    "rank": 10
                  }
                ]
              },
              "__typename": "ExternallyAccessibleNostosV1"
            },
            {
              "id": "life-sciences",
              "content": {
                "skill_data": [
                  {
                    "rank": 1,
                    "url": "https://www.coursera.org/courses?query=psychology",
                    "listIdentifier": "psychology"
                  },
                  {
                    "listIdentifier": "medicine",
                    "url": "https://www.coursera.org/courses?query=medicine",
                    "rank": 2
                  },
                  {
                    "listIdentifier": "medical",
                    "rank": 3,
                    "url": "https://www.coursera.org/courses?query=medical"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=biology",
                    "listIdentifier": "biology",
                    "rank": 4
                  },
                  {
                    "listIdentifier": "bioinformatics",
                    "rank": 5,
                    "url": "https://www.coursera.org/courses?query=bioinformatics"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=neuroscience",
                    "rank": 6,
                    "listIdentifier": "neuroscience"
                  },
                  {
                    "rank": 7,
                    "url": "https://www.coursera.org/courses?query=mental%20health",
                    "listIdentifier": "mental health"
                  },
                  {
                    "listIdentifier": "anatomy",
                    "rank": 8,
                    "url": "https://www.coursera.org/courses?query=anatomy"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=nutrition",
                    "listIdentifier": "nutrition",
                    "rank": 9
                  },
                  {
                    "listIdentifier": "pharmaceutical",
                    "url": "https://www.coursera.org/courses?query=pharmaceutical",
                    "rank": 10
                  }
                ]
              },
              "__typename": "ExternallyAccessibleNostosV1"
            },
            {
              "id": "personal-development",
              "content": {
                "skill_data": [
                  {
                    "rank": 1,
                    "url": "https://www.coursera.org/courses?query=communication%20skills",
                    "listIdentifier": "communication skills"
                  },
                  {
                    "listIdentifier": "soft skills",
                    "url": "https://www.coursera.org/courses?query=soft%20skills",
                    "rank": 2
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=critical%20thinking",
                    "rank": 3,
                    "listIdentifier": "critical thinking"
                  },
                  {
                    "listIdentifier": "teaching english",
                    "url": "https://www.coursera.org/courses?query=teaching%20english",
                    "rank": 4
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=emotional%20intelligence",
                    "rank": 5,
                    "listIdentifier": "emotional intelligence"
                  },
                  {
                    "rank": 6,
                    "url": "https://www.coursera.org/courses?query=public%20speaking",
                    "listIdentifier": "public speaking"
                  },
                  {
                    "rank": 7,
                    "url": "https://www.coursera.org/courses?query=teaching",
                    "listIdentifier": "teaching"
                  },
                  {
                    "listIdentifier": "learning how to learn",
                    "url": "https://www.coursera.org/courses?query=learning%20how%20to%20learn",
                    "rank": 8
                  },
                  {
                    "listIdentifier": "mindfulness",
                    "url": "https://www.coursera.org/courses?query=mindfulness",
                    "rank": 9
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=positive%20psychology",
                    "listIdentifier": "positive psychology",
                    "rank": 10
                  }
                ]
              },
              "__typename": "ExternallyAccessibleNostosV1"
            },
            {
              "id": "physical-science-and-engineering",
              "content": {
                "skill_data": [
                  {
                    "rank": 1,
                    "url": "https://www.coursera.org/courses?query=civil%20engineering",
                    "listIdentifier": "civil engineering"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=physics",
                    "listIdentifier": "physics",
                    "rank": 2
                  },
                  {
                    "rank": 3,
                    "url": "https://www.coursera.org/courses?query=sustainability",
                    "listIdentifier": "sustainability"
                  },
                  {
                    "listIdentifier": "electronics",
                    "url": "https://www.coursera.org/courses?query=electronics",
                    "rank": 4
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=robotics",
                    "rank": 5,
                    "listIdentifier": "robotics"
                  },
                  {
                    "rank": 6,
                    "url": "https://www.coursera.org/courses?query=autocad",
                    "listIdentifier": "autocad"
                  },
                  {
                    "rank": 7,
                    "listIdentifier": "embedded systems",
                    "url": "https://www.coursera.org/courses?query=embedded%20systems"
                  },
                  {
                    "rank": 8,
                    "listIdentifier": "astronomy",
                    "url": "https://www.coursera.org/courses?query=astronomy"
                  },
                  {
                    "listIdentifier": "gis",
                    "url": "https://www.coursera.org/courses?query=gis",
                    "rank": 9
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=chemistry",
                    "listIdentifier": "chemistry",
                    "rank": 10
                  }
                ]
              },
              "__typename": "ExternallyAccessibleNostosV1"
            },
            {
              "id": "social-sciences",
              "content": {
                "skill_data": [
                  {
                    "rank": 1,
                    "listIdentifier": "law",
                    "url": "https://www.coursera.org/courses?query=law"
                  },
                  {
                    "listIdentifier": "teaching english",
                    "url": "https://www.coursera.org/courses?query=teaching%20english",
                    "rank": 2
                  },
                  {
                    "rank": 3,
                    "listIdentifier": "international relations",
                    "url": "https://www.coursera.org/courses?query=international%20relations"
                  },
                  {
                    "listIdentifier": "economics",
                    "rank": 4,
                    "url": "https://www.coursera.org/courses?query=economics"
                  },
                  {
                    "listIdentifier": "journalism",
                    "rank": 5,
                    "url": "https://www.coursera.org/courses?query=journalism"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=teaching",
                    "rank": 6,
                    "listIdentifier": "teaching"
                  },
                  {
                    "rank": 7,
                    "url": "https://www.coursera.org/courses?query=sociology",
                    "listIdentifier": "sociology"
                  },
                  {
                    "listIdentifier": "history",
                    "url": "https://www.coursera.org/courses?query=history",
                    "rank": 8
                  },
                  {
                    "listIdentifier": "instructional design",
                    "rank": 9,
                    "url": "https://www.coursera.org/courses?query=instructional%20design"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=education",
                    "listIdentifier": "education",
                    "rank": 10
                  }
                ]
              },
              "__typename": "ExternallyAccessibleNostosV1"
            },
            {
              "id": "arts-and-humanities",
              "content": {
                "skill_data": [
                  {
                    "rank": 1,
                    "listIdentifier": "design",
                    "url": "https://www.coursera.org/courses?query=design"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=art",
                    "rank": 2,
                    "listIdentifier": "art"
                  },
                  {
                    "rank": 3,
                    "listIdentifier": "photoshop",
                    "url": "https://www.coursera.org/courses?query=photoshop"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=music",
                    "listIdentifier": "music",
                    "rank": 4
                  },
                  {
                    "listIdentifier": "photography",
                    "rank": 5,
                    "url": "https://www.coursera.org/courses?query=photography"
                  },
                  {
                    "listIdentifier": "architecture",
                    "rank": 6,
                    "url": "https://www.coursera.org/courses?query=architecture"
                  },
                  {
                    "rank": 7,
                    "url": "https://www.coursera.org/courses?query=creative%20writing",
                    "listIdentifier": "creative writing"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=art%20history",
                    "listIdentifier": "art history",
                    "rank": 8
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=drawing",
                    "listIdentifier": "drawing",
                    "rank": 9
                  },
                  {
                    "listIdentifier": "film",
                    "url": "https://www.coursera.org/courses?query=film",
                    "rank": 10
                  }
                ]
              },
              "__typename": "ExternallyAccessibleNostosV1"
            },
            {
              "id": "math-and-logic",
              "content": {
                "skill_data": [
                  {
                    "rank": 1,
                    "url": "https://www.coursera.org/courses?query=mathematics",
                    "listIdentifier": "mathematics"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=calculus",
                    "listIdentifier": "calculus",
                    "rank": 2
                  },
                  {
                    "rank": 3,
                    "url": "https://www.coursera.org/courses?query=linear%20algebra",
                    "listIdentifier": "linear algebra"
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=algebra",
                    "listIdentifier": "algebra",
                    "rank": 4
                  },
                  {
                    "url": "https://www.coursera.org/courses?query=probability",
                    "rank": 5,
                    "listIdentifier": "probability"
                  },
                  {
                    "listIdentifier": "optimization",
                    "rank": 6,
                    "url": "https://www.coursera.org/courses?query=optimization"
                  },
                  {
                    "rank": 7,
                    "url": "https://www.coursera.org/courses?query=mathematics",
                    "listIdentifier": "math"
                  },
                  {
                    "listIdentifier": "discrete mathematics",
                    "rank": 8,
                    "url": "https://www.coursera.org/courses?query=discrete%20mathematics"
                  },
                  {
                    "listIdentifier": "pre calculus",
                    "url": "https://www.coursera.org/courses?query=pre%20calculus",
                    "rank": 9
                  },
                  {
                    "listIdentifier": "mathematics for machine learning",
                    "url": "https://www.coursera.org/courses?query=mathematics%20for%20machine%20learning",
                    "rank": 10
                  }
                ]
              },
              "__typename": "ExternallyAccessibleNostosV1"
            }
          ],
          "__typename": "ExternallyAccessibleNostosV1Connection"
        },
        "__typename": "ExternallyAccessibleNostosV1Resource"
      }
    }
  }
]

# %%
# pre-processing and exploring data

data[0]['data']['ExternallyAccessibleNostosV1Resource']['getAllProperties']['elements'][0]
# Out:
# {'id': 'data-science',
#  'content': {'skill_data': [{'rank': 1,
#     'listIdentifier': 'python',
#     'url': 'https://www.coursera.org/courses?query=python'},
#    {'url': 'https://www.coursera.org/courses?query=sql',
#     'rank': 2,
#     'listIdentifier': 'sql'},
#    {'rank': 3,
#     'url': 'https://www.coursera.org/courses?query=microsoft%20excel',
#     'listIdentifier': 'microsoft excel'},
#    {'listIdentifier': 'excel',
#     'rank': 4,
#     'url': 'https://www.coursera.org/courses?query=excel'},
#    {'rank': 5,
#     'listIdentifier': 'machine learning',
#     'url': 'https://www.coursera.org/courses?query=machine%20learning'},
#    {'url': 'https://www.coursera.org/courses?query=data%20science',
#     'listIdentifier': 'data science',
#     'rank': 6},
#    {'rank': 7,
#     'url': 'https://www.coursera.org/courses?query=data%20analytics',
#     'listIdentifier': 'data analytics'},
#    {'rank': 8,
#     'url': 'https://www.coursera.org/courses?query=power%20bi',
# ...

# %%
data[0]['data']['ExternallyAccessibleNostosV1Resource']['getAllProperties']['elements'][0]['content']['skill_data'][0]['url']
# Out:
# 'https://www.coursera.org/courses?query=python'

# %%
len(data[0]['data']['ExternallyAccessibleNostosV1Resource']['getAllProperties']['elements'])
# Out:
# 11

# %%
for i in range(0, 11):
    print(data[0]['data']['ExternallyAccessibleNostosV1Resource']['getAllProperties']['elements'][i]['id'])
# Out:
# data-science
# business
# computer-science
# information-technology
# language-learning
# life-sciences
# personal-development
# physical-science-and-engineering
# social-sciences
# arts-and-humanities
# math-and-logic

# %%
scrapUrl = []


for i in range(0, len(data[0]['data']['ExternallyAccessibleNostosV1Resource']['getAllProperties']['elements'])):
    for j in range(0, len(data[0]['data']['ExternallyAccessibleNostosV1Resource']['getAllProperties']['elements'][0]['content']['skill_data'])):
        scrapUrl.append(data[0]['data']['ExternallyAccessibleNostosV1Resource']['getAllProperties']['elements'][i]['content']['skill_data'][j]['url'])

# %%
# retrieving all the skills sections

scrapUrl
# Out:
# ['https://www.coursera.org/courses?query=python',
#  'https://www.coursera.org/courses?query=sql',
#  'https://www.coursera.org/courses?query=microsoft%20excel',
#  'https://www.coursera.org/courses?query=excel',
#  'https://www.coursera.org/courses?query=machine%20learning',
#  'https://www.coursera.org/courses?query=data%20science',
#  'https://www.coursera.org/courses?query=data%20analytics',
#  'https://www.coursera.org/courses?query=power%20bi',
#  'https://www.coursera.org/courses?query=artificial%20intelligence',
#  'https://www.coursera.org/courses?query=statistics',
#  'https://www.coursera.org/courses?query=project%20management',
#  'https://www.coursera.org/courses?query=microsoft%20excel',
#  'https://www.coursera.org/courses?query=excel',
#  'https://www.coursera.org/courses?query=blockchain',
#  'https://www.coursera.org/courses?query=digital%20marketing',
#  'https://www.coursera.org/courses?query=data%20analytics',
# ...

# %%
# web crawling and scraping

import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver.common.desired_capabilities import DesiredCapabilities
import time
import os
import pandas as pd

# source_code = requests.get('http://fantasy.espn.com/basketball/league/standings?leagueId=633975')

driver = webdriver.Chrome('D:\Projects\Final Year\Zepto\chromedriver.exe')
driver.set_window_size(1920,1080)
# Out:
# C:\Users\devsh\AppData\Local\Programs\Python\Python37\lib\site-packages\ipykernel_launcher.py:11: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   # This is added back by InteractiveShellApp.init_path()

# %%
# webpage source from Coursera's HTML response analytics
# could change if Coursera changes it's HTML response

# course title
course_title_tag = 'h2'
course_title_class_name = 'cds-1 card-title css-cru2ji cds-3'

# course organization
course_organization_tag = 'span'
course_organization_class_name = 'cds-1 css-1cxz0bb cds-3'

# course certificate type
course_certificate_type_tag = 'span'
course_certificate_type_class_name = 'cds-1 css-yg35ph cds-3'

# course rating
course_rating_tag = 'span'
course_rating_class_name = 'ratings-text'

# course total ratings
course_total_ratings_tag = 'span'
course_total_ratings_class_name = 'ratings-count'

# course difficulty
course_difficulty_tag = 'span'
course_difficulty_class_name = 'cds-1 difficulty css-1vjdgz cds-3'

# course enrollment
course_enrollment_tag = 'span'
course_enrollment_class_name = 'enrollment-number'

# course URL
course_URL_tag = 'a'
course_URL_class_name = 'result-title-link'

# %%
# other needed functions

def __append_element__(scraper, html_tag, class_name):
    storeValues = []
    
    for element in scraper.find_all(html_tag, class_name):
        storeValues.append(element.get_text())
    
    return storeValues


def __append_element_href__(scraper, html_tag, class_name):
    storeValues = []
    
    for element in scraper.find_all(html_tag, class_name):
        storeValues.append('https://www.coursera.org' + element['href'])
    
    return storeValues

# %%
# scraper and crawler

def __parameter__():
    storeValues = [[],[],[],[],[],[],[],[]]
    pageNumber = 1
    check = True
    query = 0
    field_names = [
        'Title',
        'Organization',
        'Certificate',
        'Rating',
        'Total Ratings',
        'Difficulty',
        'Enrollment',
        'Link'
    ]
    
    # scraping algorithm
    while query < 10:
        while check:
            driver.get('https://www.coursera.org/search?query=' + scrapUrl[query].split('=')[1] + '&page=' + str(pageNumber) + '&index=prod_all_launched_products_term_optimization')
            time.sleep(2)
            
            page_source = driver.page_source
            scraper = BeautifulSoup(page_source, 'html.parser')
        
            if len(scraper.find_all(course_title_tag,course_title_class_name)) > 0 and pageNumber < 5:
                storeValues[0].append(__append_element__(scraper, course_title_tag, course_title_class_name))
                storeValues[1].append(__append_element__(scraper, course_organization_tag, course_organization_class_name))
                storeValues[2].append(__append_element__(scraper, course_certificate_type_tag, course_certificate_type_class_name))
                storeValues[3].append(__append_element__(scraper, course_rating_tag, course_rating_class_name))
                storeValues[4].append(__append_element__(scraper, course_total_ratings_tag, course_total_ratings_class_name))
                storeValues[5].append(__append_element__(scraper, course_difficulty_tag, course_difficulty_class_name))
                storeValues[6].append(__append_element__(scraper, course_enrollment_tag, course_enrollment_class_name))
                storeValues[7].append(__append_element_href__(scraper, course_URL_tag, course_URL_class_name))
                pageNumber = pageNumber + 1
                
                # saving data to csv file
                for i in range(0, len(storeValues[0][0])):
                    data = [
                        {'Title': storeValues[0][0][i],
                        'Organization': storeValues[1][0][i],
                        'Certificate': storeValues[2][0][i],
                        'Rating': storeValues[3][0][i],
                        'Total Ratings': storeValues[4][0][i],
                        'Difficulty': storeValues[5][0][i],
                        'Enrollment': storeValues[6][0][i],
                        'Link': storeValues[7][0][i]}
                    ]
                
                    with open('Coursera.csv', 'a', encoding="utf-8") as csvfile:
                        writer = csv.DictWriter(csvfile, fieldnames=field_names)
                        writer.writerows(data)
                
            else:
                check = False
                
        
        # resetting values 
        check = True
        query = query + 1
        pageNumber = 1

# %%
# scraper
__parameter__()
